# %%
# Test API Endpoint
import requests

url = 'https://ml.googleapis.com/v1/projects/irtizak-titanic/models/irtizak_titanic_1/versions/test:predict'
myobj = {
            "instances": [
                [1.0, 38.0, 1.0, 0.0, 71.2833, 1.0, 0.0],
                [3.0, 22.0, 1.0, 0.0, 7.25, 0.0, 1.0]
            ]
        }

x = requests.post(url, data = myobj)

print(x.text)
