# %%
# Import libraries 
import requests

# %%
# Test with input as JSON file
# !curl -X POST -H "Content-Type: application/json" -d @input.json \
-H "Authorization: Bearer `gcloud auth print-access-token`" \
"https://us-central1-ml.googleapis.com/v1/projects/irtizak-titanic/models/irtizak_titanic_1/versions/test:predict"
# Out:
# {"predictions": [1, 0]}

# %%
# Test with input as parameter
# !curl -X POST -H "Content-Type: application/json" -d '{"instances": [[1.0, 38.0, 1.0, 0.0, 71.2833, 1.0, 0.0], [3.0, 22.0, 1.0, 0.0, 7.25, 0.0, 1.0]]}' \
-H "Authorization: Bearer `gcloud auth print-access-token`" \
"https://us-central1-ml.googleapis.com/v1/projects/irtizak-titanic/models/irtizak_titanic_1/versions/test:predict"
# Out:
# {"predictions": [1, 0]}
